# %%
# !python --version
# Out:
# Python 3.8.3

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\user\anaconda3\lib\site-packages (3.11.1)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in c:\users\user\anaconda3\lib\site-packages (from pymongo[srv]) (1.16.0)

# %%
import pymongo
from pymongo import MongoClient

pymongo.version
# Out:
# '3.11.1'

# %%
client = pymongo.MongoClient("mongodb+srv://life-healthy:life-healthy-root@life-healthy-cl-au4c3.mongodb.net/test?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['test', 'admin', 'local']

# %%
db = client.anatel

# %%
db.minas
# Out:
# Collection(Database(MongoClient(host=['life-healthy-cl-shard-00-01-au4c3.mongodb.net:27017', 'life-healthy-cl-shard-00-00-au4c3.mongodb.net:27017', 'life-healthy-cl-shard-00-02-au4c3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='life-healthy-cl-shard-0', ssl=True), 'anatel'), 'minas')

# %%
db.minas.count_documents({}) # Quantos documentos possui a coleção minas?
# Out:
# 509706

# %%
list(db.minas.find().limit(5)) # Mostre os 5 primeiros documentos da coleção.
# Out:
# [{'_id': ObjectId('5fbd9a20de628f32f085048e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085048f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5fbd9a20de628f32f0850490'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850491'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850492'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1}]

# %%
valueMax = db.minas.find_one(sort=[("QtdeSolic", -1)]) # Selecione o documento que possui o maior número de solicitações QtdeSolic na Anatel.
valueMax['QtdeSolic']
# Out:
# 4164

# %%
valueMin = db.minas.find_one(sort=[("QtdeSolic", 1)]) # Qual é o menor número de solicitações QtdeSolic na Anatel?
valueMin['QtdeSolic']
# Out:
# 1

# %%
minValue = db.minas.find_one(sort=[("QtdeSolic", 1)])
value = minValue['QtdeSolic']
list(db.minas.find({ "QtdeSolic": value })) # Mostre todos os documentos com o menor número de solicitações QtdeSolic na Anatel.
# Out:
# [{'_id': ObjectId('5fbd9a20de628f32f0850490'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850491'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850492'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850493'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850494'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850498'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085049b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085049c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085049d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ac'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ae'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio Comunitária',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504af'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504b2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504b4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504b9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504bb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504bc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Licenciamento e instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504bf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Resposta de solicitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504cc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504cf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504da'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504e3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504e4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504e8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504eb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ec'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Prestadoras',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504fb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504fc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504fd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ff'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850502'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850503'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850504'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850505'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850506'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Limitado Privado',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850507'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850508'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085050c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085050d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085050e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850513'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850517'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085051a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085051d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085051e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Atuação da Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850520'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850521'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850522'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850524'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850526'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850528'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850529'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085052b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085052f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850530'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'GVT',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850531'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850533'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850536'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850537'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085053d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850544'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850545'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850546'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850548'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850549'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085054c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085054f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850551'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850556'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085055a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085055e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850561'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850562'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850566'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085056b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085056d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085056e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interrupções no Serviço de Localidades',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850571'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850576'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850577'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085057a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850581'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085058e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850592'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085059b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085059c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505ac'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505b0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505b6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505b8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505b9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505bb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505bc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505c9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505cb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505cf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505d1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505d3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505d5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505de'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505df'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Contrato de prestação de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505e0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505eb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08505ec'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
# ...
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bdc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bdd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bde'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bdf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850be0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850be4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850be6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Central de Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850be7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'MMDS (Via Microondas)',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850be8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850be9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850beb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Sala do Cidadão',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bec'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Documentos emitidos pela Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bed'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bef'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Produtos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Definição',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Portal Anatel',
#   'Motivo': 'Link Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bf9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bfa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850bfb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c00'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c03'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c05'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c06'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c07'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c09'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c0a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c0b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c0c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c0d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c0f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c11'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c12'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c13'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c15'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c16'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c1a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a22de628f32f0850c1b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  ...]

# %%
# Mostre as contagens de solicitações QtdeSolic por tipo de serviço Servico, em ordem decrescente pelas contagens

# %%
list(db.minas.find({ 'Tipo': 'Reclamação' })) #Mostre todos os documentos com atributo Tipo igual a "Reclamação".
# Out:
# [{'_id': ObjectId('5fbd9a20de628f32f0850490'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850491'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850492'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850493'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850494'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850495'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850496'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 9},
#  {'_id': ObjectId('5fbd9a20de628f32f0850497'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 29},
#  {'_id': ObjectId('5fbd9a20de628f32f0850498'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850499'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085049a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 12},
#  {'_id': ObjectId('5fbd9a20de628f32f085049b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085049c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085049d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085049e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 10},
#  {'_id': ObjectId('5fbd9a20de628f32f085049f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 15},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 7},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f08504a9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a20de628f32f08504aa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cartão Telefônico',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ab'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f08504c9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504cb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f08504cc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504cd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504ce'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f08504cf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 62},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f08504d9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504da'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f08504db'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a20de628f32f08504dc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a20de628f32f08504dd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f08504de'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850506'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Limitado Privado',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850507'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850508'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850509'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Atuação da Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5fbd9a20de628f32f085050a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Central de Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5fbd9a20de628f32f085050f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5fbd9a20de628f32f0850510'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850511'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 9},
#  {'_id': ObjectId('5fbd9a20de628f32f0850512'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850513'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850514'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850515'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a20de628f32f0850516'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a20de628f32f0850517'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850518'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 13},
#  {'_id': ObjectId('5fbd9a20de628f32f0850519'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f0850521'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850527'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f0850528'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850529'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085052a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f085052b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085052c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085052d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085052e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f085052f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850530'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'GVT',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850532'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850533'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850534'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850535'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850536'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850538'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 159},
#  {'_id': ObjectId('5fbd9a20de628f32f0850539'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 25},
#  {'_id': ObjectId('5fbd9a20de628f32f085053a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5fbd9a20de628f32f085053b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 39},
#  {'_id': ObjectId('5fbd9a20de628f32f085053c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085053d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085053e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 50},
#  {'_id': ObjectId('5fbd9a20de628f32f085053f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 7},
#  {'_id': ObjectId('5fbd9a20de628f32f0850540'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850541'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5fbd9a20de628f32f0850542'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cartão Telefônico',
#   'UF': 'MG',
#   'QtdeSolic': 10},
#  {'_id': ObjectId('5fbd9a20de628f32f0850543'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NEXTEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Troncalizado (Trunking)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850547'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a20de628f32f0850548'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850549'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085054a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f085054b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085054c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085054d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5fbd9a20de628f32f085054e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 22},
#  {'_id': ObjectId('5fbd9a20de628f32f085054f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850550'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 9},
#  {'_id': ObjectId('5fbd9a20de628f32f0850551'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f0850552'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850553'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a20de628f32f0850554'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a20de628f32f0850555'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 12},
#  {'_id': ObjectId('5fbd9a20de628f32f0850557'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f0850558'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 93},
#  {'_id': ObjectId('5fbd9a20de628f32f0850559'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 46},
#  {'_id': ObjectId('5fbd9a20de628f32f085055a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085055b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a20de628f32f085055c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 22},
#  {'_id': ObjectId('5fbd9a20de628f32f085055d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5fbd9a20de628f32f085055e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a20de628f32f085055f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 22},
#  {'_id': ObjectId('5fbd9a20de628f32f0850560'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 14},
#  {'_id': ObjectId('5fbd9a20de628f32f0850561'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
# ...
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850960'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 22},
#  {'_id': ObjectId('5fbd9a21de628f32f0850961'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 58},
#  {'_id': ObjectId('5fbd9a21de628f32f0850962'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 26},
#  {'_id': ObjectId('5fbd9a21de628f32f0850963'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 71},
#  {'_id': ObjectId('5fbd9a21de628f32f0850964'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a21de628f32f0850965'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 44},
#  {'_id': ObjectId('5fbd9a21de628f32f0850966'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a21de628f32f0850967'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a21de628f32f0850968'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a21de628f32f0850969'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a21de628f32f085096a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 10},
#  {'_id': ObjectId('5fbd9a21de628f32f085096b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 147},
#  {'_id': ObjectId('5fbd9a21de628f32f085096c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5fbd9a21de628f32f085096d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 38},
#  {'_id': ObjectId('5fbd9a21de628f32f085096f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 16},
#  {'_id': ObjectId('5fbd9a21de628f32f0850970'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 107},
#  {'_id': ObjectId('5fbd9a21de628f32f0850971'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 47},
#  {'_id': ObjectId('5fbd9a21de628f32f0850972'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850973'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a21de628f32f0850974'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 12},
#  {'_id': ObjectId('5fbd9a21de628f32f0850975'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 18},
#  {'_id': ObjectId('5fbd9a21de628f32f0850976'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850977'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 7},
#  {'_id': ObjectId('5fbd9a21de628f32f0850978'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 72},
#  {'_id': ObjectId('5fbd9a21de628f32f0850979'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a21de628f32f085097a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 83},
#  {'_id': ObjectId('5fbd9a21de628f32f085097b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5fbd9a21de628f32f085097c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 92},
#  {'_id': ObjectId('5fbd9a21de628f32f085097d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fbd9a21de628f32f085097e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 13},
#  {'_id': ObjectId('5fbd9a21de628f32f085097f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850980'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850981'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a21de628f32f0850982'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a21de628f32f0850983'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850984'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbd9a21de628f32f0850985'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850986'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5fbd9a21de628f32f0850987'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f0850988'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5fbd9a21de628f32f0850989'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5fbd9a21de628f32f085098a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbd9a21de628f32f085098b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  ...]

# %%
list(db.minas.distictint('Tipo')) #Quais diferentes valores encontramos em Tipo?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-5ff4a556d256> in <module>
# ----> 1 list(db.minas.distictint('Tipo')) #Quais diferentes valores encontramos em Tipo?
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in __call__(self, *args, **kwargs)
#    3443                             "exists." %
#    3444                             self.__name)
# -> 3445         raise TypeError("'Collection' object is not callable. If you meant to "
#    3446                         "call the '%s' method on a 'Collection' object it is "
#    3447                         "failing because no such method exists." %
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'distictint' method on a 'Collection' object it is failing because no such method exists.
